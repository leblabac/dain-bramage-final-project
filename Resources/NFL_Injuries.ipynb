# %%
# Import Dependencies
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager
import requests
import pandas as pd

# %%
# Set up Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [C:\Users\krist\.wdm\drivers\chromedriver\win32\98.0.4758.80\chromedriver.exe] found in cache

# %%
# Visit the Quotes to Scrape site
url = 'https://www.nfl.com/injuries/'
browser.visit(url)
# Create object page
page = requests.get(url)

# %%
# # Parse the HTML
# html = browser.html
# html_soup = soup(html, 'html.parser')

# parser-lxml = Change html to Python friendly format
# Obtain page's information
html_soup = soup(page.text, 'html.parser')
print(html_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://www.nfl.com/injuries/" rel="canonical"/>
#   <link href="//nflenterprises.tt.omtrdc.net" rel="dns-prefetch"/>
#   <link href="//securepubads.g.doubleclick.net" rel="preconnect"/>
#   <link href="//cdn.onesignal.com" rel="preconnect"/>
#   <link href="//assets.adobedtm.com" rel="preconnect"/>
#   <script async="" type="text/javascript">
# ...

# %%
# Obtain information from tag <table>
table = html_soup.find('div', class_='d3-o-table--horizontal-scroll')
print(table)
# Out:
# <div class="d3-o-table--horizontal-scroll">
# <table class="d3-o-table d3-o-table--detailed d3-o-reports--detailed">
# <thead>
# <tr>
# <th>Player</th>
# <th>Position</th>
# <th>Injuries</th>
# <th>Practice Status</th>
# <th>Game Status</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td scope="row" tabindex="0">
# <a aria-label="Visit Grant Haley profile page" class="nfl-o-cta--link" href="/players/grant-haley/">
#                     Grant Haley
#                   </a>
# </td>
# <td>
#               CB
#             </td>
# <td>
# </td>
# <td>
#               Full Participation in Practice
#             </td>
# <td>
# </td>
# </tr>
# <tr>
# <td scope="row" tabindex="0">
# <a aria-label="Visit Tyler Higbee profile page" class="nfl-o-cta--link" href="/players/tyler-higbee/">
#                     Tyler Higbee
#                   </a>
# </td>
# <td>
#               TE
#             </td>
# <td>
# </td>
# <td>
#               Did Not Participate In Practice
#             </td>
# <td>
# ...

# %%
df = pd.read_html('https://www.nfl.com/injuries/')[0]
df.columns=['Player', 'Position', 'Injuries', 'Practice Status', 'Game Status']
# df.set_index('description', inplace=True)
df
# Out:
#                Player Position  Injuries                    Practice Status  \
# 0         Grant Haley       CB       NaN     Full Participation in Practice
# 1        Tyler Higbee       TE       NaN    Did Not Participate In Practice
# 2           Cam Akers       RB       NaN     Full Participation in Practice
# 3        Jalen Ramsey       CB       NaN     Full Participation in Practice
# 4         Taylor Rapp        S       NaN     Full Participation in Practice
# 5    Andrew Whitworth        T       NaN     Full Participation in Practice
# 6       Van Jefferson       WR       NaN     Full Participation in Practice
# 7        Joe Noteboom        T       NaN  Limited Participation in Practice
# 8  Christian Rozeboom       LB       NaN     Full Participation in Practice
#
#    Game Status
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN

# %%
df.shape
# Out:
# (9, 5)

# %%
df1 = pd.read_html('https://www.nfl.com/injuries/')[1]
df1.columns=['Player', 'Position', 'Injuries', 'Practice Status', 'Game Status']
# df.set_index('description', inplace=True)
df1
# Out:
#            Player Position Injuries                 Practice Status  \
# 0  Cameron Sample       DE      NaN  Full Participation in Practice
# 1     C.J. Uzomah       TE     Knee  Full Participation in Practice
# 2  Stanley Morgan       WR      NaN  Full Participation in Practice
# 3      Josh Tupou       DT      NaN  Full Participation in Practice
# 4  Jackson Carman        G      NaN  Full Participation in Practice
#
#     Game Status
# 0           NaN
# 1  Questionable
# 2           NaN
# 3           NaN
# 4           NaN
