# %%
import os
import glob
import pandas as pd
import csv

# %%
# Import csv file
df = pd.read_csv("NFL_Yearly_Breakdown_combined.csv")
#find null values
print(df.isnull())
# Out:
#        Rank  Player   Year    Pos   Team  Draft Year  BaseSalary  \
# 0      True   False  False  False  False       False       False
# 1      True   False  False  False  False       False       False
# 2      True   False  False  False  False       False       False
# 3      True   False  False  False  False       False       False
# 4      True   False  False  False  False       False       False
# ...     ...     ...    ...    ...    ...         ...         ...
# 24852  True   False  False  False  False       False       False
# 24853  True   False  False  False  False       False       False
# 24854  True   False  False  False  False       False       False
# 24855  True   False  False  False  False       False       False
# 24856  True   False  False  False  False       False       False
#
#        SigningBonus  Cap Hit  Salary%   Cash    AAV  CONT YR  CONT VALUE  \
# 0             False    False    False  False  False    False       False
# ...

# %%
#drop columns that have no use in dataset
gross_Cap_Statistics_df = df.drop(columns=["Rank", "Unnamed: 19", "FA Year", "Sign Year", "Sign Age", "Draft Year", "Cash", "Earnings", "CONT VALUE", "CONT YR", "AAV"])
#drop future year rows
gross_Cap_Statistics_df= gross_Cap_Statistics_df[gross_Cap_Statistics_df.Year != 2023]
gross_Cap_Statistics_df= gross_Cap_Statistics_df[gross_Cap_Statistics_df.Year != 2024]
gross_Cap_Statistics_df
# Out:
#                    Player  Year  Pos Team   BaseSalary SigningBonus  \
# 0            Mark Sanchez  2011   QB  NYJ  $14,225,000           $0
# 1          Dwight Freeney  2011  OLB  IND  $11,420,000   $2,500,000
# 2        Larry Fitzgerald  2011   WR  ARI   $2,000,000   $5,000,000
# 3          Mario Williams  2011   DE  HOU  $13,800,000           $0
# 4          Peyton Manning  2011   QB  IND   $3,400,000   $4,000,000
# ...                   ...   ...  ...  ...          ...          ...
# 23651    Austen Pleasants  2022    T  CAR     $705,000           $0
# 23652       C.J. Saunders  2022   WR  CAR     $705,000           $0
# 23653         Jesse James  2022   TE  CHI           $0     $162,500
# 23654  Odell Beckham, Jr.  2022   WR  LAR           $0     $100,000
# 23655     Damien Williams  2022   RB  CHI           $0     $125,000
#
#            Cap Hit  Salary%  Age
# 0      $17,228,125    0.134   25
# 1      $16,420,000    0.134   31
# 2      $16,250,000    0.133   28
# ...

# %%
# write DF to new csv
# gross_Cap_Statistics_df.to_csv("Gross_Cap_Stats.csv",index=False)

# %%
gross_Cap_Statistics_df
# Out:
#                    Player  Year  Pos Team   BaseSalary SigningBonus  \
# 0            Mark Sanchez  2011   QB  NYJ  $14,225,000           $0
# 1          Dwight Freeney  2011  OLB  IND  $11,420,000   $2,500,000
# 2        Larry Fitzgerald  2011   WR  ARI   $2,000,000   $5,000,000
# 3          Mario Williams  2011   DE  HOU  $13,800,000           $0
# 4          Peyton Manning  2011   QB  IND   $3,400,000   $4,000,000
# ...                   ...   ...  ...  ...          ...          ...
# 23651    Austen Pleasants  2022    T  CAR     $705,000           $0
# 23652       C.J. Saunders  2022   WR  CAR     $705,000           $0
# 23653         Jesse James  2022   TE  CHI           $0     $162,500
# 23654  Odell Beckham, Jr.  2022   WR  LAR           $0     $100,000
# 23655     Damien Williams  2022   RB  CHI           $0     $125,000
#
#            Cap Hit  Salary%  Age
# 0      $17,228,125    0.134   25
# 1      $16,420,000    0.134   31
# 2      $16,250,000    0.133   28
# ...
