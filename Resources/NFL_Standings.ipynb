# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# Import our data into pandas from CSV
nfl_standings_path = 'nfl_standings.csv'
nfl_standings_df = pd.read_csv(nfl_standings_path)

nfl_standings_df
# Out:
#      season conf   division team  wins  losses  ties       pct  div_rank  \
# 0      2021  AFC   AFC East  BUF    11       6     0  0.647059         1
# 1      2021  AFC   AFC East  MIA     9       8     0  0.529412         3
# 2      2021  AFC   AFC East   NE    10       7     0  0.588235         2
# 3      2021  AFC   AFC East  NYJ     4      13     0  0.235294         4
# 4      2021  AFC  AFC North  BAL     8       9     0  0.470588         4
# ..      ...  ...        ...  ...   ...     ...   ...       ...       ...
# 635    2002  NFC  NFC South   TB    12       4     0  0.750000         1
# 636    2002  NFC   NFC West  ARI     5      11     0  0.312500         4
# 637    2002  NFC   NFC West  SEA     7       9     0  0.437500         3
# 638    2002  NFC   NFC West   SF    10       6     0  0.625000         1
# 639    2002  NFC   NFC West  STL     7       9     0  0.437500         2
#
#      scored  allowed  net       sov       sos  seed playoff
# 0       483      289  194  0.427807  0.472318   3.0  LostDV
# 1       341      373  -32  0.379085  0.463668   NaN     NaN
# 2       462      303  159  0.394118  0.480969   6.0  LostWC
# 3       310      504 -194  0.426471  0.512111   NaN     NaN
# 4       387      392   -5  0.459559  0.531142   NaN     NaN
# ..      ...      ...  ...       ...       ...   ...     ...
# 635     346      196  150  0.427083  0.476562   2.0   WonSB
# 636     262      417 -155  0.400000  0.500000   NaN     NaN
# 637     355      369  -14  0.428571  0.503906   NaN     NaN
# 638     367      351   16  0.450000  0.503906   4.0  LostDV
# 639     316      369  -53  0.446429  0.507812   NaN     NaN
#
# [640 rows x 16 columns]

# %%
# Change column headings
nfl_standings_df = nfl_standings_df.rename(columns={"season":"year", "pct":"win %"})
nfl_standings_df
# Out:
#      year conf   division team  wins  losses  ties     win %  div_rank  \
# 0    2021  AFC   AFC East  BUF    11       6     0  0.647059         1
# 1    2021  AFC   AFC East  MIA     9       8     0  0.529412         3
# 2    2021  AFC   AFC East   NE    10       7     0  0.588235         2
# 3    2021  AFC   AFC East  NYJ     4      13     0  0.235294         4
# 4    2021  AFC  AFC North  BAL     8       9     0  0.470588         4
# ..    ...  ...        ...  ...   ...     ...   ...       ...       ...
# 635  2002  NFC  NFC South   TB    12       4     0  0.750000         1
# 636  2002  NFC   NFC West  ARI     5      11     0  0.312500         4
# 637  2002  NFC   NFC West  SEA     7       9     0  0.437500         3
# 638  2002  NFC   NFC West   SF    10       6     0  0.625000         1
# 639  2002  NFC   NFC West  STL     7       9     0  0.437500         2
#
#      scored  allowed  net       sov       sos  seed playoff
# 0       483      289  194  0.427807  0.472318   3.0  LostDV
# 1       341      373  -32  0.379085  0.463668   NaN     NaN
# 2       462      303  159  0.394118  0.480969   6.0  LostWC
# 3       310      504 -194  0.426471  0.512111   NaN     NaN
# 4       387      392   -5  0.459559  0.531142   NaN     NaN
# ..      ...      ...  ...       ...       ...   ...     ...
# 635     346      196  150  0.427083  0.476562   2.0   WonSB
# 636     262      417 -155  0.400000  0.500000   NaN     NaN
# 637     355      369  -14  0.428571  0.503906   NaN     NaN
# 638     367      351   16  0.450000  0.503906   4.0  LostDV
# 639     316      369  -53  0.446429  0.507812   NaN     NaN
#
# [640 rows x 16 columns]

# %%
# Combine records of renamed teams
nfl_standings_df["team"].replace({"LA":"LAR/STL", "STL":"LAR/STL", "LV": "LV/OAK", 
            "OAK": "LV/OAK", "SD":"LAC/SD", "LAC":"LAC/SD"},inplace=True)
nfl_standings_df.tail(32)
# Out:
#      year conf   division     team  wins  losses  ties    win %  div_rank  \
# 608  2002  AFC   AFC East      BUF     8       8     0  0.50000         4
# 609  2002  AFC   AFC East      MIA     9       7     0  0.56250         3
# 610  2002  AFC   AFC East       NE     9       7     0  0.56250         2
# 611  2002  AFC   AFC East      NYJ     9       7     0  0.56250         1
# 612  2002  AFC  AFC North      BAL     7       9     0  0.43750         3
# 613  2002  AFC  AFC North      CIN     2      14     0  0.12500         4
# 614  2002  AFC  AFC North      CLE     9       7     0  0.56250         2
# 615  2002  AFC  AFC North      PIT    10       5     1  0.65625         1
# 616  2002  AFC  AFC South      HOU     4      12     0  0.25000         4
# 617  2002  AFC  AFC South      IND    10       6     0  0.62500         2
# 618  2002  AFC  AFC South      JAX     6      10     0  0.37500         3
# 619  2002  AFC  AFC South      TEN    11       5     0  0.68750         1
# 620  2002  AFC   AFC West      DEN     9       7     0  0.56250         2
# 621  2002  AFC   AFC West       KC     8       8     0  0.50000         4
# 622  2002  AFC   AFC West   LV/OAK    11       5     0  0.68750         1
# 623  2002  AFC   AFC West   LAC/SD     8       8     0  0.50000         3
# 624  2002  NFC   NFC East      DAL     5      11     0  0.31250         4
# 625  2002  NFC   NFC East      NYG    10       6     0  0.62500         2
# 626  2002  NFC   NFC East      PHI    12       4     0  0.75000         1
# 627  2002  NFC   NFC East      WAS     7       9     0  0.43750         3
# 628  2002  NFC  NFC North      CHI     4      12     0  0.25000         3
# 629  2002  NFC  NFC North      DET     3      13     0  0.18750         4
# 630  2002  NFC  NFC North       GB    12       4     0  0.75000         1
# 631  2002  NFC  NFC North      MIN     6      10     0  0.37500         2
# 632  2002  NFC  NFC South      ATL     9       6     1  0.59375         2
# 633  2002  NFC  NFC South      CAR     7       9     0  0.43750         4
# 634  2002  NFC  NFC South       NO     9       7     0  0.56250         3
# 635  2002  NFC  NFC South       TB    12       4     0  0.75000         1
# 636  2002  NFC   NFC West      ARI     5      11     0  0.31250         4
# 637  2002  NFC   NFC West      SEA     7       9     0  0.43750         3
# 638  2002  NFC   NFC West       SF    10       6     0  0.62500         1
# 639  2002  NFC   NFC West  LAR/STL     7       9     0  0.43750         2
#
#      scored  allowed  net       sov       sos  seed playoff
# 608     379      397  -18  0.351562  0.472656   NaN     NaN
# 609     378      301   77  0.486111  0.507812   NaN     NaN
# 610     381      346   35  0.451389  0.523438   NaN     NaN
# 611     359      336   23  0.500000  0.500000   4.0  LostDV
# 612     316      354  -38  0.383929  0.500000   NaN     NaN
# 613     279      456 -177  0.406250  0.531250   NaN     NaN
# 614     344      320   24  0.409722  0.480469   6.0  LostWC
# 615     390      345   45  0.443750  0.484375   3.0  LostDV
# 616     213      356 -143  0.484375  0.515625   NaN     NaN
# 617     349      313   36  0.400000  0.476562   5.0  LostWC
# 618     328      315   13  0.437500  0.503906   NaN     NaN
# 619     367      324   43  0.471591  0.476562   2.0  LostCC
# 620     392      344   48  0.486111  0.527344   NaN     NaN
# 621     467      399   68  0.515625  0.527344   NaN     NaN
# 622     450      304  146  0.528409  0.527344   1.0  LostSB
# 623     333      367  -34  0.453125  0.492188   NaN     NaN
# 624     217      329 -112  0.475000  0.500000   NaN     NaN
# 625     320      279   41  0.450000  0.480469   5.0  LostWC
# 626     415      241  174  0.432292  0.468750   1.0  LostCC
# 627     307      365  -58  0.437500  0.527344   NaN     NaN
# 628     281      379  -98  0.421875  0.519531   NaN     NaN
# 629     306      451 -145  0.375000  0.492188   NaN     NaN
# 630     398      328   70  0.411458  0.449219   3.0  LostWC
# 631     390      442  -52  0.416667  0.496094   NaN     NaN
# 632     402      314   88  0.416667  0.492188   6.0  LostDV
# 633     258      302  -44  0.357143  0.480469   NaN     NaN
# 634     432      388   44  0.562500  0.492188   NaN     NaN
# 635     346      196  150  0.427083  0.476562   2.0   WonSB
# 636     262      417 -155  0.400000  0.500000   NaN     NaN
# 637     355      369  -14  0.428571  0.503906   NaN     NaN
# 638     367      351   16  0.450000  0.503906   4.0  LostDV
# 639     316      369  -53  0.446429  0.507812   NaN     NaN

# %%
# Drop years of data prior to 2011
nfl_standings_df.drop(nfl_standings_df.loc[nfl_standings_df["year"] < 2011].index, inplace=True)
nfl_standings_df
# Out:
#      year conf   division     team  wins  losses  ties     win %  div_rank  \
# 0    2021  AFC   AFC East      BUF    11       6     0  0.647059         1
# 1    2021  AFC   AFC East      MIA     9       8     0  0.529412         3
# 2    2021  AFC   AFC East       NE    10       7     0  0.588235         2
# 3    2021  AFC   AFC East      NYJ     4      13     0  0.235294         4
# 4    2021  AFC  AFC North      BAL     8       9     0  0.470588         4
# ..    ...  ...        ...      ...   ...     ...   ...       ...       ...
# 347  2011  NFC  NFC South       TB     4      12     0  0.250000         4
# 348  2011  NFC   NFC West      ARI     8       8     0  0.500000         2
# 349  2011  NFC   NFC West      SEA     7       9     0  0.437500         3
# 350  2011  NFC   NFC West       SF    13       3     0  0.812500         1
# 351  2011  NFC   NFC West  LAR/STL     2      14     0  0.125000         4
#
#      scored  allowed  net       sov       sos  seed playoff
# 0       483      289  194  0.427807  0.472318   3.0  LostDV
# 1       341      373  -32  0.379085  0.463668   NaN     NaN
# 2       462      303  159  0.394118  0.480969   6.0  LostWC
# 3       310      504 -194  0.426471  0.512111   NaN     NaN
# 4       387      392   -5  0.459559  0.531142   NaN     NaN
# ..      ...      ...  ...       ...       ...   ...     ...
# 347     287      494 -207  0.437500  0.550781   NaN     NaN
# 348     312      348  -36  0.390625  0.468750   NaN     NaN
# 349     321      315    6  0.437500  0.511719   NaN     NaN
# 350     380      229  151  0.418269  0.449219   2.0  LostCC
# 351     193      407 -214  0.531250  0.589844   NaN     NaN
#
# [352 rows x 16 columns]

# %%
# nfl_standings_df["playoff"] = pd.replace(nfl_standings_df["playoff"] == "LostSB","Yes", inplace=True)
nfl_standings_df["playoff"].replace({"LostSB":"Yes", "LostCC":"Yes", "LostDV": "Yes", 
            "LostWC": "Yes", "WonSB":"Yes" },inplace=True)

nfl_standings_df
# Out:
#      year conf   division     team  wins  losses  ties     win %  div_rank  \
# 0    2021  AFC   AFC East      BUF    11       6     0  0.647059         1
# 1    2021  AFC   AFC East      MIA     9       8     0  0.529412         3
# 2    2021  AFC   AFC East       NE    10       7     0  0.588235         2
# 3    2021  AFC   AFC East      NYJ     4      13     0  0.235294         4
# 4    2021  AFC  AFC North      BAL     8       9     0  0.470588         4
# ..    ...  ...        ...      ...   ...     ...   ...       ...       ...
# 347  2011  NFC  NFC South       TB     4      12     0  0.250000         4
# 348  2011  NFC   NFC West      ARI     8       8     0  0.500000         2
# 349  2011  NFC   NFC West      SEA     7       9     0  0.437500         3
# 350  2011  NFC   NFC West       SF    13       3     0  0.812500         1
# 351  2011  NFC   NFC West  LAR/STL     2      14     0  0.125000         4
#
#      scored  allowed  net       sov       sos  seed playoff
# 0       483      289  194  0.427807  0.472318   3.0     Yes
# 1       341      373  -32  0.379085  0.463668   NaN     NaN
# 2       462      303  159  0.394118  0.480969   6.0     Yes
# 3       310      504 -194  0.426471  0.512111   NaN     NaN
# 4       387      392   -5  0.459559  0.531142   NaN     NaN
# ..      ...      ...  ...       ...       ...   ...     ...
# 347     287      494 -207  0.437500  0.550781   NaN     NaN
# 348     312      348  -36  0.390625  0.468750   NaN     NaN
# 349     321      315    6  0.437500  0.511719   NaN     NaN
# 350     380      229  151  0.418269  0.449219   2.0     Yes
# 351     193      407 -214  0.531250  0.589844   NaN     NaN
#
# [352 rows x 16 columns]

# %%
# Replace NaN values with "No"
nfl_standings_df["playoff"].fillna("No", inplace = True)
nfl_standings_df
# Out:
#      year conf   division     team  wins  losses  ties     win %  div_rank  \
# 0    2021  AFC   AFC East      BUF    11       6     0  0.647059         1
# 1    2021  AFC   AFC East      MIA     9       8     0  0.529412         3
# 2    2021  AFC   AFC East       NE    10       7     0  0.588235         2
# 3    2021  AFC   AFC East      NYJ     4      13     0  0.235294         4
# 4    2021  AFC  AFC North      BAL     8       9     0  0.470588         4
# ..    ...  ...        ...      ...   ...     ...   ...       ...       ...
# 347  2011  NFC  NFC South       TB     4      12     0  0.250000         4
# 348  2011  NFC   NFC West      ARI     8       8     0  0.500000         2
# 349  2011  NFC   NFC West      SEA     7       9     0  0.437500         3
# 350  2011  NFC   NFC West       SF    13       3     0  0.812500         1
# 351  2011  NFC   NFC West  LAR/STL     2      14     0  0.125000         4
#
#      scored  allowed  net       sov       sos  seed playoff
# 0       483      289  194  0.427807  0.472318   3.0     Yes
# 1       341      373  -32  0.379085  0.463668   NaN      No
# 2       462      303  159  0.394118  0.480969   6.0     Yes
# 3       310      504 -194  0.426471  0.512111   NaN      No
# 4       387      392   -5  0.459559  0.531142   NaN      No
# ..      ...      ...  ...       ...       ...   ...     ...
# 347     287      494 -207  0.437500  0.550781   NaN      No
# 348     312      348  -36  0.390625  0.468750   NaN      No
# 349     321      315    6  0.437500  0.511719   NaN      No
# 350     380      229  151  0.418269  0.449219   2.0     Yes
# 351     193      407 -214  0.531250  0.589844   NaN      No
#
# [352 rows x 16 columns]

# %%
# Checking "playoff" column values to make sure previous cell was successful.
nfl_standings_df["playoff"].values
# Out:
# array(['Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No',
#        'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No',
#        'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes',
#        'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes',
#        'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No',
#        'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes',
#        'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No',
#        'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'No',
#        'No', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No',
#        'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No',
#        'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes',
#        'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No',
#        'No', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No',
#        'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes',
#        'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No',
#        'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'No',
#        'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No',
#        'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'No',
#        'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes',
#        'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No',
#        'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes',
#        'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No',
#        'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No',
#        'No', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No',
#        'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No',
#        'Yes', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No',
#        'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes',
#        'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes',
#        'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Yes',
#        'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No',
#        'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No',
#        'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No',
#        'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Yes',
#        'No'], dtype=object)

# %%
# nfl_standings_df.loc[(nfl_standings_df['playoff'] == "")] = "No"
nfl_standings_df['playoff'] = nfl_standings_df['playoff'].fillna("0")
nfl_standings_df.loc[(nfl_standings_df['playoff'] == 0)] = "No"
nfl_standings_df
# Out:
#      year conf   division     team wins losses ties     win % div_rank scored  \
# 0    2021  AFC   AFC East      BUF   11      6    0  0.647059        1    483
# 1    2021  AFC   AFC East      MIA    9      8    0  0.529412        3    341
# 2    2021  AFC   AFC East       NE   10      7    0  0.588235        2    462
# 3    2021  AFC   AFC East      NYJ    4     13    0  0.235294        4    310
# 4    2021  AFC  AFC North      BAL    8      9    0  0.470588        4    387
# ..    ...  ...        ...      ...  ...    ...  ...       ...      ...    ...
# 347  2011  NFC  NFC South       TB    4     12    0      0.25        4    287
# 348  2011  NFC   NFC West      ARI    8      8    0       0.5        2    312
# 349  2011  NFC   NFC West      SEA    7      9    0    0.4375        3    321
# 350  2011  NFC   NFC West       SF   13      3    0    0.8125        1    380
# 351  2011  NFC   NFC West  LAR/STL    2     14    0     0.125        4    193
#
#     allowed   net       sov       sos seed playoff
# 0       289   194  0.427807  0.472318  3.0     Yes
# 1       373   -32  0.379085  0.463668  NaN      No
# 2       303   159  0.394118  0.480969  6.0     Yes
# 3       504  -194  0.426471  0.512111  NaN      No
# 4       392    -5  0.459559  0.531142  NaN      No
# ..      ...   ...       ...       ...  ...     ...
# 347     494  -207    0.4375  0.550781  NaN      No
# 348     348   -36  0.390625   0.46875  NaN      No
# 349     315     6    0.4375  0.511719  NaN      No
# 350     229   151  0.418269  0.449219  2.0     Yes
# 351     407  -214   0.53125  0.589844  NaN      No
#
# [352 rows x 16 columns]

# %%
# create new colum for "superbowl winner"
# Polulate column with superbown winner "yes" and "No" accordingly.
#(code to be written here)

# %%
# export to csv
nfl_standings_path = 'nfl_standings_r3.csv'
nfl_standings_df.to_csv(nfl_standings_path)
