# %%
# Import Dependencies

import pandas as pd
import numpy as np

# %%
# load and read csv file into DataFrame

merged_file_to_load = "NFL_Merged_df.csv"
NFL_Merged_df = pd.read_csv(merged_file_to_load)
NFL_Merged_df
# Out:
#        Unnamed: 0            Player  Age  Year  Pos  Cat_POS Team  BaseSalary  \
# 0               0      Mark Sanchez   25  2011   QB  Offense  NYJ    14225000
# 1               1    Dwight Freeney   31  2011  OLB  Defense  IND    11420000
# 2               2  Larry Fitzgerald   28  2011   WR  Offense  ARI     2000000
# 3               3    Mario Williams   26  2011   DE  Defense  HOU    13800000
# 4               4    Peyton Manning   35  2011   QB  Offense  IND     3400000
# ...           ...               ...  ...   ...  ...      ...  ...         ...
# 21996       21996  Stephen Sullivan   25  2021   WR  Offense  CAR       36666
# 21997       21997        Jalen Camp   23  2021   WR  Offense  HOU       36666
# 21998       21998  Michael Dwumfour   23  2021   DT  Defense  HOU       36666
# 21999       21999       Tarik Black   23  2021   WR  Offense  NYJ       36666
# 22000       22000   Connor Strachan   26  2021   LB  Defense  HOU       36666
#
# ...

# %%
# Drop column

NFL_Merged_df = NFL_Merged_df.drop(columns = "Unnamed: 0")
NFL_Merged_df.head()
# Out:
#              Player  Age  Year  Pos  Cat_POS Team  BaseSalary  SigningBonus  \
# 0      Mark Sanchez   25  2011   QB  Offense  NYJ    14225000             0
# 1    Dwight Freeney   31  2011  OLB  Defense  IND    11420000       2500000
# 2  Larry Fitzgerald   28  2011   WR  Offense  ARI     2000000       5000000
# 3    Mario Williams   26  2011   DE  Defense  HOU    13800000             0
# 4    Peyton Manning   35  2011   QB  Offense  IND     3400000       4000000
#
#     Cap Hit  Salary%  ... Ties  Win %  Div_Rank  Scored  Allowed  Net  \
# 0  17228125    0.134  ...    0  0.500         2     377      363   14
# 1  16420000    0.134  ...    0  0.125         4     243      430 -187
# 2  16250000    0.133  ...    0  0.500         2     312      348  -36
# 3  16200000    0.135  ...    0  0.625         1     381      278  103
# 4  16000000    0.130  ...    0  0.125         4     243      430 -187
#
#         SOV       SOS  Playoff  Won Superbowl
# ...

# %%
# Verify years in Dataset

NFL_Merged_df.Year.unique()
# Out:
# array([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021],
#       dtype=int64)

# %%
#  Create 11 seperate Dataframes for each year

# Create dataframe for 2011 only

values = [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
df2011 = pd.DataFrame(NFL_Merged_df[NFL_Merged_df.Year.isin(values)==False])


df2011
# Out:
#                 Player  Age  Year  Pos  Cat_POS     Team  BaseSalary  \
# 0         Mark Sanchez   25  2011   QB  Offense      NYJ    14225000
# 1       Dwight Freeney   31  2011  OLB  Defense      IND    11420000
# 2     Larry Fitzgerald   28  2011   WR  Offense      ARI     2000000
# 3       Mario Williams   26  2011   DE  Defense      HOU    13800000
# 4       Peyton Manning   35  2011   QB  Offense      IND     3400000
# ...                ...  ...   ...  ...      ...      ...         ...
# 1615        Pat Devlin   23  2011   QB  Offense      MIA       44117
# 1616       Armon Binns   22  2011   WR  Offense      CIN       44117
# 1617        Ricky Sapp   25  2011  OLB  Defense      NYJ       22059
# 1618     Jordan Todman   21  2011   RB  Offense      MIN       22058
# 1619      Kevin Hughes   23  2011    T  Offense  LAR/STL           0
#
#       SigningBonus   Cap Hit  Salary%  ... Ties   Win %  Div_Rank  Scored  \
# ...

# %%
# Create dataframe for 2012 only

values = [2011, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
df2012 = pd.DataFrame(NFL_Merged_df[NFL_Merged_df.Year.isin(values)==False])

df2012
# Out:
#                Player  Age  Year  Pos  Cat_POS     Team  BaseSalary  \
# 1620   Dwight Freeney   32  2012  OLB  Defense      IND    14035000
# 1621       Chris Long   27  2012   DE  Defense  LAR/STL    10310000
# 1622   Peyton Manning   36  2012   QB  Offense      DEN    18000000
# 1623   Patrick Willis   27  2012  ILB  Defense       SF     1904000
# 1624   Elvis Dumervil   28  2012  OLB  Defense      DEN    14000000
# ...               ...  ...   ...  ...      ...      ...         ...
# 3427   Jamell Fleming   23  2012    S  Defense      ARI       45882
# 3428   Eddie Pleasant   24  2012   FS  Defense      HOU      390000
# 3429   Brett Brackett   25  2012   TE  Offense      JAX       22941
# 3430     Kevin Hughes   24  2012    T  Offense  LAR/STL           0
# 3431  Andrew McDonald   24  2012   RT  Offense      MIA        1500
#
#       SigningBonus   Cap Hit  Salary%  ... Ties    Win %  Div_Rank  Scored  \
# ...

# %%
# Create dataframe for 2013 only

values = [2011, 2012, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
df2013 = pd.DataFrame(NFL_Merged_df[NFL_Merged_df.Year.isin(values)==False])

df2013
# Out:
#                 Player  Age  Year Pos  Cat_POS Team  BaseSalary  SigningBonus  \
# 3432       Eli Manning   32  2013  QB  Offense  NYG    13000000       2600000
# 3433  Matthew Stafford   25  2013  QB  Offense  DET     4000000       5500000
# 3434    Peyton Manning   37  2013  QB  Offense  DEN    15000000             0
# 3435        Drew Brees   34  2013  QB  Offense   NO     9750000       7400000
# 3436       Jared Allen   31  2013  DE  Defense  MIN    14280612       2583344
# ...                ...  ...   ...  ..      ...  ...         ...           ...
# 5296        Ray Graham   23  2013  RB  Offense  HOU      405000             0
# 5297      Toben Opurum   23  2013  DE  Defense  HOU      405000             0
# 5298     Sheldon Price   22  2013  CB  Defense  IND      405000             0
# 5299    Kanorris Davis   23  2013   S  Defense   NE      405000             0
# 5300       Jumal Rolle   23  2013  CB  Defense   GB      405000             0
#
# ...

# %%
# Create dataframe for 2014 only

values = [2011, 2012, 2013, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
df2014 = pd.DataFrame(NFL_Merged_df[NFL_Merged_df.Year.isin(values)==False])

df2014
# Out:
#                   Player  Age  Year Pos        Cat_POS Team  BaseSalary  \
# 5301       Ndamukong Suh   27  2014  DT        Defense  DET    12550000
# 5302        Gerald McCoy   26  2014  DT        Defense   TB    17500000
# 5303         Eli Manning   33  2014  QB        Offense  NYG    15150000
# 5304  Ben Roethlisberger   32  2014  QB        Offense  PIT    12100000
# 5305      Mario Williams   29  2014  DE        Defense  BUF     1900000
# ...                  ...  ...   ...  ..            ...  ...         ...
# 7289        Jerome Smith   23  2014  RB        Offense  ATL      420000
# 7290    Charley Hughlett   24  2014  LS  Special Teams  CLE      420000
# 7291         Connor Shaw   23  2014  QB        Offense  CLE      420000
# 7292         Henry Josey   23  2014  RB        Offense  MIN      420000
# 7293        Chris Whaley   24  2014  DT        Defense  DAL           0
#
#       SigningBonus   Cap Hit  Salary%  ... Ties   Win %  Div_Rank  Scored  \
# ...

# %%
# Create dataframe for 2015 only

values = [2011, 2012, 2013, 2014, 2016, 2017, 2018, 2019, 2020, 2021]
df2015 = pd.DataFrame(NFL_Merged_df[NFL_Merged_df.Year.isin(values)==False])

df2015
# Out:
#                Player  Age  Year Pos  Cat_POS     Team  BaseSalary  \
# 7294       Drew Brees   36  2015  QB  Offense       NO    13550000
# 7295    Philip Rivers   34  2015  QB  Offense   LAC/SD    15000000
# 7296   Calvin Johnson   30  2015  WR  Offense      DET    12500000
# 7297  Charles Johnson   29  2015  DE  Defense      CAR     9750000
# 7298        Matt Ryan   30  2015  QB  Offense      ATL    11500000
# ...               ...  ...   ...  ..      ...      ...         ...
# 9366     Toben Opurum   25  2015  DE  Defense       NO       25588
# 9367    Malcolm Brown   22  2015  RB  Offense  LAR/STL       25588
# 9368        Troy Hill   24  2015  CB  Defense  LAR/STL       25588
# 9369    D.J. Tialavea   24  2015  TE  Offense      ATL       25588
# 9370      Richard Ash   23  2015  DT  Defense      JAX       25588
#
#       SigningBonus   Cap Hit  Salary%  ... Ties   Win %  Div_Rank  Scored  \
# 7294       7400000  23800000    0.164  ...    0  0.4375         3     408
# ...

# %%
# Create dataframe for 2016 only

values = [2011, 2012, 2013, 2014, 2015, 2017, 2018, 2019, 2020, 2021]
df2016 = pd.DataFrame(NFL_Merged_df[NFL_Merged_df.Year.isin(values)==False])

df2016
# Out:
#                    Player  Age  Year  Pos  Cat_POS    Team  BaseSalary  \
# 9371          Eli Manning   35  2016   QB  Offense     NYG    17500000
# 9372   Ben Roethlisberger   34  2016   QB  Offense     PIT    17750000
# 9373            Matt Ryan   31  2016   QB  Offense     ATL    15750000
# 9374           Joe Flacco   31  2016   QB  Offense     BAL     4000000
# 9375     Matthew Stafford   28  2016   QB  Offense     DET    17000000
# ...                   ...  ...   ...  ...      ...     ...         ...
# 11464      Taveze Calhoun   24  2016    S  Defense      NO       26470
# 11465       Brandon Burks   23  2016   RB  Offense     NYJ       26470
# 11466       Bryson Keeton   23  2016   CB  Defense     NYJ       26470
# 11467       Carlos Fields   26  2016  OLB  Defense  LAC/SD       26470
# 11468      Kasen Williams   24  2016   WR  Offense     SEA       26470
#
#        SigningBonus   Cap Hit  Salary%  ... Ties    Win %  Div_Rank  Scored  \
# ...

# %%
# Create dataframe for 2017 only

values = [2011, 2012, 2013, 2014, 2015, 2016, 2018, 2019, 2020, 2021]
df2017 = pd.DataFrame(NFL_Merged_df[NFL_Merged_df.Year.isin(values)==False])

df2017
# Out:
#                  Player  Age  Year  Pos  Cat_POS Team  BaseSalary  \
# 11469        Joe Flacco   32  2017   QB  Offense  BAL     6000000
# 11470     Carson Palmer   38  2017   QB  Offense  ARI    15500000
# 11471      Kirk Cousins   29  2017   QB  Offense  WAS    23943600
# 11472         Matt Ryan   32  2017   QB  Offense  ATL    15750000
# 11473    Justin Houston   28  2017  OLB  Defense   KC    16350000
# ...                 ...  ...   ...  ...      ...  ...         ...
# 13587  Quincy Adeboyejo   22  2017   WR  Offense  BAL       27353
# 13588       Trae Elston   23  2017    S  Defense  MIA       27353
# 13589    Adam Bisnowaty   24  2017    T  Offense  NYG       27353
# 13590   Demetri Goodson   28  2017   CB  Defense   GB           0
# 13591     Jamil Douglas   25  2017    C  Offense  ATL       20470
#
#        SigningBonus   Cap Hit  Salary%  ... Ties   Win %  Div_Rank  Scored  \
# 11469      13800000  24550000    0.150  ...    0  0.5625         2     395
# ...

# %%
# Create dataframe for 2018 only

values = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2019, 2020, 2021]
df2018 = pd.DataFrame(NFL_Merged_df[NFL_Merged_df.Year.isin(values)==False])

df2018
# Out:
#                  Player  Age  Year Pos  Cat_POS    Team  BaseSalary  \
# 13592   Jimmy Garoppolo   27  2018  QB  Offense      SF     6200000
# 13593  Matthew Stafford   30  2018  QB  Offense     DET     9500000
# 13594        Derek Carr   27  2018  QB  Offense  LV/OAK     7400000
# 13595        Joe Flacco   33  2018  QB  Offense     BAL    12000000
# 13596       Andrew Luck   29  2018  QB  Offense     IND    12000000
# ...                 ...  ...   ...  ..      ...     ...         ...
# 15688     Blake Jackson   24  2018  WR  Offense     CLE       28235
# 15689    Brandon Bryant   23  2018  CB  Defense     NYJ       28235
# 15690        J.J. Jones   26  2018  WR  Offense     NYJ       28235
# 15691    Jimmy Williams   23  2018  WR  Offense     DEN      480000
# 15692     Alex Thompson   23  2018   C  Offense     BAL      480000
#
#        SigningBonus   Cap Hit  Salary%  ... Ties    Win %  Div_Rank  Scored  \
# ...

# %%
# Create dataframe for 2019 only

values = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2020, 2021]
df2019 = pd.DataFrame(NFL_Merged_df[NFL_Merged_df.Year.isin(values)==False])

df2019
# Out:
#                    Player  Age  Year  Pos  Cat_POS Team  BaseSalary  \
# 15693    Matthew Stafford   31  2019   QB  Offense  DET    13500000
# 15694       Aaron Rodgers   36  2019   QB  Offense   GB     1100000
# 15695        Kirk Cousins   31  2019   QB  Offense  MIN    27500000
# 15696      Russell Wilson   31  2019   QB  Offense  SEA     5000000
# 15697  Ben Roethlisberger   37  2019   QB  Offense  PIT     2500000
# ...                   ...  ...   ...  ...      ...  ...         ...
# 17805         Dee Delaney   24  2019   CB  Defense  WAS       29118
# 17806         Jester Weah   24  2019   WR  Offense  WAS       29118
# 17807       Chris Slayton   23  2019   DT  Defense  NYG       29118
# 17808        Quinn Bailey   24  2019    T  Offense  DEN       29118
# 17809       Darius Harris   23  2019  OLB  Defense   KC      320000
#
#        SigningBonus   Cap Hit  Salary%  ... Ties    Win %  Div_Rank  Scored  \
# ...

# %%
# Create dataframe for 2020 only

values = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2021]
df2020 = pd.DataFrame(NFL_Merged_df[NFL_Merged_df.Year.isin(values)==False])

df2020
# Out:
#                 Player  Age  Year  Pos  Cat_POS     Team  BaseSalary  \
# 17810     Dak Prescott   27  2020   QB  Offense      DAL    31409000
# 17811   Russell Wilson   32  2020   QB  Offense      SEA    18000000
# 17812       Jared Goff   26  2020   QB  Offense  LAR/STL     1042682
# 17813      Khalil Mack   29  2020  OLB  Defense      CHI    13300000
# 17814  Jimmy Garoppolo   29  2020   QB  Offense       SF    23800000
# ...                ...  ...   ...  ...      ...      ...         ...
# 19844      Nate Holley   26  2020    S  Defense      MIA       35882
# 19845       Geno Stone   21  2020   SS  Defense      HOU       35882
# 19846     Rashod Berry   24  2020   TE  Offense       NE       35882
# 19847     Cassh Maluia   22  2020   LB  Defense       NE       35882
# 19848   Delrick Abrams   23  2020   CB  Defense      ATL       33582
#
#        SigningBonus   Cap Hit  Salary%  ... Ties   Win %  Div_Rank  Scored  \
# ...

# %%
# Create dataframe for 2021 only

values = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
df2021 = pd.DataFrame(NFL_Merged_df[NFL_Merged_df.Year.isin(values)==False])

df2021
# Out:
#                  Player  Age  Year Pos  Cat_POS Team  BaseSalary  \
# 19849    Russell Wilson   33  2021  QB  Offense  SEA    19000000
# 19850      Kirk Cousins   33  2021  QB  Offense  MIN    21000000
# 19851     Aaron Rodgers   38  2021  QB  Offense   GB     1100000
# 19852         Matt Ryan   36  2021  QB  Offense  ATL     2000000
# 19853   Jimmy Garoppolo   30  2021  QB  Offense   SF    24100000
# ...                 ...  ...   ...  ..      ...  ...         ...
# 21996  Stephen Sullivan   25  2021  WR  Offense  CAR       36666
# 21997        Jalen Camp   23  2021  WR  Offense  HOU       36666
# 21998  Michael Dwumfour   23  2021  DT  Defense  HOU       36666
# 21999       Tarik Black   23  2021  WR  Offense  NYJ       36666
# 22000   Connor Strachan   26  2021  LB  Defense  HOU       36666
#
#        SigningBonus   Cap Hit  Salary%  ... Ties     Win %  Div_Rank  Scored  \
# 19849      13000000  32000000    0.174  ...    0  0.411765         4     395
# ...

# %%
# Verify total row count

# 2011 - 1620 rows
# 2012 - 1812 rows
# 2013 - 1869 rows
# 2014 - 1993 rows
# 2015 - 2077 rows
# 2016 - 2098 rows
# 2017 - 2123 rows
# 2018 - 2101 rows
# 2019 - 2117 rows
# 2019 - 2039 rows
# 2019 - 2152 rows
# Total = 22001 rows
# NFL_merged = 22001 rows
# :)

# All Dataframes have 24 columns


# Note: It looks like the number of players has increased quite a bit over the past decade

# %%
# export to csv

df2011_path = "df2011.csv"
df2011.to_csv(df2011_path)

df2012_path = "df2012.csv"
df2012.to_csv(df2012_path)

df2013_path = "df2013.csv"
df2013.to_csv(df2013_path)

df2014_path = "df2014.csv"
df2014.to_csv(df2014_path)

df2015_path = "df2015.csv"
df2015.to_csv(df2015_path)

df2016_path = "df2016.csv"
df2016.to_csv(df2016_path)

df2017_path = "df2017.csv"
df2017.to_csv(df2017_path)

df2018_path = "df2018.csv"
df2018.to_csv(df2018_path)

df2019_path = "df2019.csv"
df2019.to_csv(df2019_path)

df2020_path = "df2020.csv"
df2020.to_csv(df2020_path)

df2021_path = "df2021.csv"
df2021.to_csv(df2021_path)
