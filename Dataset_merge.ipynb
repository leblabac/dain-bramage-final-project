# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# # Import standings into pandas from CSV
# nfl_standings_path = 'nfl_standings_r4.csv'
# nfl_standings_df = pd.read_csv(nfl_standings_path)

# # Import statistics into pandas from CSV
# nfl_statistics_path = 'nfl_statistics_r1.xlsx'
# nfl_statistics_df = pd.read_excel(nfl_statistics_path)

# %%
# reading csv files
nfl_standings = pd.read_csv('nfl_standings_r5.csv')
nfl_financials = pd.read_csv('financials_r1.csv')

# # using merge function by setting how='left'
# output2 = pd.merge(nfl_standings, nfl_financials,
#                    on=('Team', 'Year')
#                    how='left')

# # displaying result
# print(output2)

# %%
NFL_Merged_df = pd.merge(nfl_financials, nfl_standings,  how='left', left_on=['Year','Team'], right_on = ['Year','Team'])
NFL_Merged_df
# Out:
#        Unnamed: 0_x            Player  Year  Pos Team   BaseSalary  \
# 0                 0      Mark Sanchez  2011   QB  NYJ  $14,225,000
# 1                 1    Dwight Freeney  2011  OLB  IND  $11,420,000
# 2                 2  Larry Fitzgerald  2011   WR  ARI   $2,000,000
# 3                 3    Mario Williams  2011   DE  HOU  $13,800,000
# 4                 4    Peyton Manning  2011   QB  IND   $3,400,000
# ...             ...               ...   ...  ...  ...          ...
# 21996         21996  Stephen Sullivan  2021   WR  CAR      $36,666
# 21997         21997        Jalen Camp  2021   WR  HOU      $36,666
# 21998         21998  Michael Dwumfour  2021   DT  HOU      $36,666
# 21999         21999       Tarik Black  2021   WR  NYJ      $36,666
# 22000         22000   Connor Strachan  2021   LB  HOU      $36,666
#
#       SigningBonus      Cap Hit  Salary%  Unnamed: 0_y  ... Ties     Win %  \
# 0               $0  $17,228,125    0.134           323  ...    0  0.500000
# ...

# %%
NFL_Merged_df = NFL_Merged_df.drop(columns="Unnamed: 0_x")

# %%
NFL_Merged_df = NFL_Merged_df.drop(columns="Unnamed: 0_y")

# %%
Positions = [
    (NFL_Merged_df["Pos"] == "C"),
    (NFL_Merged_df["Pos"] == "FB"),
    (NFL_Merged_df["Pos"] == "G"),
    (NFL_Merged_df["Pos"] == "LT"),
    (NFL_Merged_df["Pos"] == "QB"),
    (NFL_Merged_df["Pos"] == "RB"),
    (NFL_Merged_df["Pos"] == "RT"),
    (NFL_Merged_df["Pos"] == "T"),
    (NFL_Merged_df["Pos"] == "TE"),
    (NFL_Merged_df["Pos"] == "WR"),
    (NFL_Merged_df["Pos"] == "CB"),
    (NFL_Merged_df["Pos"] == "DE"),
    (NFL_Merged_df["Pos"] == "DT"),
    (NFL_Merged_df["Pos"] == "FS"),
    (NFL_Merged_df["Pos"] == "ILB"),
    (NFL_Merged_df["Pos"] == "LB"),
    (NFL_Merged_df["Pos"] == "OLB"),
    (NFL_Merged_df["Pos"] == "S"),
    (NFL_Merged_df["Pos"] == "SS"),
    (NFL_Merged_df["Pos"] == "K"),
    (NFL_Merged_df["Pos"] == "LS"),
    (NFL_Merged_df["Pos"] == "P")
]
# Create a list of the values to assign for each condition
values = ["Offense", "Offense", "Offense", "Offense", "Offense", "Offense", "Offense", "Offense", "Offense", "Offense",
          "Defense", "Defense", "Defense", "Defense", "Defense", "Defense", "Defense", "Defense", "Defense","Special Teams",
          "Special Teams","Special Teams"]

# create a new column and use np.select to assign values for winning column
NFL_Merged_df["Cat_POS"] = np.select(Positions, values)

# display updated DataFrame
NFL_Merged_df.head(32)
# Out:
#                  Player  Year  Pos     Team   BaseSalary SigningBonus  \
# 0          Mark Sanchez  2011   QB      NYJ  $14,225,000           $0
# 1        Dwight Freeney  2011  OLB      IND  $11,420,000   $2,500,000
# 2      Larry Fitzgerald  2011   WR      ARI   $2,000,000   $5,000,000
# 3        Mario Williams  2011   DE      HOU  $13,800,000           $0
# 4        Peyton Manning  2011   QB      IND   $3,400,000   $4,000,000
# 5            Joe Thomas  2011   LT      CLE   $8,000,000   $2,260,000
# 6        Elvis Dumervil  2011  OLB      DEN  $14,000,000     $500,000
# 7          Michael Vick  2011   QB      PHI  $10,000,000   $1,400,000
# 8        Calvin Johnson  2011   WR      DET   $8,875,000   $2,800,000
# 9           Eli Manning  2011   QB      NYG   $8,500,000   $2,600,000
# 10        Philip Rivers  2011   QB   LAC/SD   $8,400,000   $3,910,000
# 11            Matt Ryan  2011   QB      ATL  $11,250,000   $2,000,000
# ...

# %%
column_names= ["Player","Year","Pos","Cat_POS","Team","BaseSalary","SigningBonus","Cap Hit","Salary%","Conf","Division","Wins","Losses","Ties","Win %","Div_Rank","Scored","Allowed","Net","SOV","SOS","Playoff","Won Superbowl"]
NFL_Merged_df= NFL_Merged_df.reindex(columns=column_names)
NFL_Merged_df
# Out:
#                  Player  Year  Pos  Cat_POS Team   BaseSalary SigningBonus  \
# 0          Mark Sanchez  2011   QB  Offense  NYJ  $14,225,000           $0
# 1        Dwight Freeney  2011  OLB  Defense  IND  $11,420,000   $2,500,000
# 2      Larry Fitzgerald  2011   WR  Offense  ARI   $2,000,000   $5,000,000
# 3        Mario Williams  2011   DE  Defense  HOU  $13,800,000           $0
# 4        Peyton Manning  2011   QB  Offense  IND   $3,400,000   $4,000,000
# ...                 ...   ...  ...      ...  ...          ...          ...
# 21996  Stephen Sullivan  2021   WR  Offense  CAR      $36,666           $0
# 21997        Jalen Camp  2021   WR  Offense  HOU      $36,666           $0
# 21998  Michael Dwumfour  2021   DT  Defense  HOU      $36,666           $0
# 21999       Tarik Black  2021   WR  Offense  NYJ      $36,666           $0
# 22000   Connor Strachan  2021   LB  Defense  HOU      $36,666           $0
#
# ...

# %%
NFL_Merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22001 entries, 0 to 22000
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player         22001 non-null  object
#  1   Year           22001 non-null  int64
#  2   Pos            22001 non-null  object
#  3   Cat_POS        22001 non-null  object
#  4   Team           22001 non-null  object
#  5   BaseSalary     22001 non-null  object
#  6   SigningBonus   22001 non-null  object
#  7   Cap Hit        22001 non-null  object
#  8   Salary%        22001 non-null  float64
#  9   Conf           22001 non-null  object
#  10  Division       22001 non-null  object
#  11  Wins           22001 non-null  int64
#  12  Losses         22001 non-null  int64
#  13  Ties           22001 non-null  int64
#  14  Win %          22001 non-null  float64
#  15  Div_Rank       22001 non-null  int64
#  16  Scored         22001 non-null  int64
# ...

# %%
# changed datatype for 3 columns to integers (base salary, signing bonus, cap hit)

NFL_Merged_df["BaseSalary"] = NFL_Merged_df["BaseSalary"].str.replace(',', '')
NFL_Merged_df["BaseSalary"] = NFL_Merged_df["BaseSalary"].str.replace('$', '')
NFL_Merged_df["BaseSalary"] = NFL_Merged_df["BaseSalary"].astype(int)

NFL_Merged_df["SigningBonus"] = NFL_Merged_df["SigningBonus"].str.replace(',', '')
NFL_Merged_df["SigningBonus"] = NFL_Merged_df["SigningBonus"].str.replace('$', '')
NFL_Merged_df["SigningBonus"] = NFL_Merged_df["SigningBonus"].astype(int)

NFL_Merged_df["Cap Hit"] = NFL_Merged_df["Cap Hit"].str.replace(',', '')
NFL_Merged_df["Cap Hit"] = NFL_Merged_df["Cap Hit"].str.replace('$', '')
NFL_Merged_df["Cap Hit"] = NFL_Merged_df["Cap Hit"].astype(int)


NFL_Merged_df.info()
NFL_Merged_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22001 entries, 0 to 22000
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player         22001 non-null  object
#  1   Year           22001 non-null  int64
#  2   Pos            22001 non-null  object
#  3   Cat_POS        22001 non-null  object
#  4   Team           22001 non-null  object
#  5   BaseSalary     22001 non-null  int32
#  6   SigningBonus   22001 non-null  int32
#  7   Cap Hit        22001 non-null  int32
#  8   Salary%        22001 non-null  float64
#  9   Conf           22001 non-null  object
#  10  Division       22001 non-null  object
#  11  Wins           22001 non-null  int64
#  12  Losses         22001 non-null  int64
#  13  Ties           22001 non-null  int64
#  14  Win %          22001 non-null  float64
#  15  Div_Rank       22001 non-null  int64
#  16  Scored         22001 non-null  int64
# ...

# %%
NFL_Merged_df.info()
NFL_Merged_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22001 entries, 0 to 22000
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player         22001 non-null  object
#  1   Year           22001 non-null  int64
#  2   Pos            22001 non-null  object
#  3   Cat_POS        22001 non-null  object
#  4   Team           22001 non-null  object
#  5   BaseSalary     22001 non-null  int32
#  6   SigningBonus   22001 non-null  int32
#  7   Cap Hit        22001 non-null  int32
#  8   Salary%        22001 non-null  float64
#  9   Conf           22001 non-null  object
#  10  Division       22001 non-null  object
#  11  Wins           22001 non-null  int64
#  12  Losses         22001 non-null  int64
#  13  Ties           22001 non-null  int64
#  14  Win %          22001 non-null  float64
#  15  Div_Rank       22001 non-null  int64
#  16  Scored         22001 non-null  int64
# ...

# %%
NFL_Merged_df.to_csv('Merged_dataset_r1.csv')
