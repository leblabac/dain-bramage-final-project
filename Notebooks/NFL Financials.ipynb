# %%
# Add dependencies
import os
import pandas as pd
import csv

# %%
# Files to load
financials_to_load = "Resources/NFL_Yearly_Breakdown_combined.csv"

# %%
# Read the financials data file and store it in a Pandas DataFrame.
financials_df = pd.read_csv(financials_to_load)
financials_df
# Out:
#        Rank              Player  Year  Pos Team  Draft Year   BaseSalary  \
# 0       NaN        Mark Sanchez  2011   QB  NYJ        2009  $14,225,000
# 1       NaN      Dwight Freeney  2011  OLB  IND        2002  $11,420,000
# 2       NaN    Larry Fitzgerald  2011   WR  ARI        2004   $2,000,000
# 3       NaN      Mario Williams  2011   DE  HOU        2006  $13,800,000
# 4       NaN      Peyton Manning  2011   QB  IND        1998   $3,400,000
# ...     ...                 ...   ...  ...  ...         ...          ...
# 24852   NaN        Bradley Roby  2024   CB   NO        2014           $0
# 24853   NaN         Jesse James  2024   TE  CHI        2015           $0
# 24854   NaN     Damien Williams  2024   RB  CHI         -99           $0
# 24855   NaN    Tanoh Kpassagnon  2024   DE   NO        2017           $0
# 24856   NaN  Odell Beckham, Jr.  2024   WR  LAR        2014           $0
#
#       SigningBonus      Cap Hit  Salary%         Cash          AAV  CONT YR  \
# ...

# %%
# Determine if there are any missing values in the financial data.
financials_df.count()
# Out:
# Rank                0
# Player          24857
# Year            24857
# Pos             24857
# Team            24857
# Draft Year      24857
# BaseSalary      24857
# SigningBonus    24857
# Cap Hit         24857
# Salary%         24857
# Cash            24857
# AAV             24857
# CONT YR         24857
# CONT VALUE      24857
# Earnings        24857
# FA Year         24857
# Sign Year       24857
# Sign Age        24857
# Age             24857
# Unnamed: 19         0
# dtype: int64

# %%
# Determine if there are any missing values in the financial data.
financials_df.isnull()
# Out:
#        Rank  Player   Year    Pos   Team  Draft Year  BaseSalary  \
# 0      True   False  False  False  False       False       False
# 1      True   False  False  False  False       False       False
# 2      True   False  False  False  False       False       False
# 3      True   False  False  False  False       False       False
# 4      True   False  False  False  False       False       False
# ...     ...     ...    ...    ...    ...         ...         ...
# 24852  True   False  False  False  False       False       False
# 24853  True   False  False  False  False       False       False
# 24854  True   False  False  False  False       False       False
# 24855  True   False  False  False  False       False       False
# 24856  True   False  False  False  False       False       False
#
#        SigningBonus  Cap Hit  Salary%   Cash    AAV  CONT YR  CONT VALUE  \
# 0             False    False    False  False  False    False       False
# ...

# %%
# Drop 
financials_df = financials_df.drop(columns=["Rank","Unnamed: 19","Age", "FA Year", "Sign Year", "Sign Age","Cash","Draft Year","AAV","CONT YR","CONT VALUE","Earnings"])

# %%
#define values
values = [2022, 2023, 2024]

#drop rows that contain any value in the list
financials_df = financials_df[financials_df.Year.isin(values) == False]
financials_df
# Out:
#                  Player  Year  Pos Team   BaseSalary SigningBonus  \
# 0          Mark Sanchez  2011   QB  NYJ  $14,225,000           $0
# 1        Dwight Freeney  2011  OLB  IND  $11,420,000   $2,500,000
# 2      Larry Fitzgerald  2011   WR  ARI   $2,000,000   $5,000,000
# 3        Mario Williams  2011   DE  HOU  $13,800,000           $0
# 4        Peyton Manning  2011   QB  IND   $3,400,000   $4,000,000
# ...                 ...   ...  ...  ...          ...          ...
# 21996  Stephen Sullivan  2021   WR  CAR      $36,666           $0
# 21997        Jalen Camp  2021   WR  HOU      $36,666           $0
# 21998  Michael Dwumfour  2021   DT  HOU      $36,666           $0
# 21999       Tarik Black  2021   WR  NYJ      $36,666           $0
# 22000   Connor Strachan  2021   LB  HOU      $36,666           $0
#
#            Cap Hit  Salary%
# 0      $17,228,125    0.134
# 1      $16,420,000    0.134
# 2      $16,250,000    0.133
# 3      $16,200,000    0.135
# ...

# %%
# Determine if there are any missing values in the financial data.
financials_df.count()
# Out:
# Player          22001
# Year            22001
# Pos             22001
# Team            22001
# BaseSalary      22001
# SigningBonus    22001
# Cap Hit         22001
# Salary%         22001
# dtype: int64

# %%
financials_df.dtypes
# Out:
# Player           object
# Year              int64
# Pos              object
# Team             object
# BaseSalary       object
# SigningBonus     object
# Cap Hit          object
# Salary%         float64
# dtype: object

# %%
# Combine records of renamed teams
financials_df["Team"].replace({"LAR":"LAR/STL", "STL":"LAR/STL", "JAC":"JAX","LV": "LV/OAK","OAK": "LV/OAK", "SD":"LAC/SD", "LAC":"LAC/SD"},inplace=True)
financials_df.tail(50)
# Out:
#                   Player  Year  Pos Team BaseSalary SigningBonus  Cap Hit  \
# 21951        Herb Miller  2021   CB  CLE    $43,333           $0  $43,333
# 21952  Jaryd Jones-Smith  2021    T  BAL    $43,333           $0  $43,333
# 21953      Jabari Zuniga  2021   DE  NYJ    $43,333           $0  $43,333
# 21954      D'Angelo Ross  2021   CB   NE    $36,666           $0  $36,666
# 21955       Quinn Bailey  2021    T  DEN    $36,666           $0  $36,666
# 21956    Tyrie Cleveland  2021   WR  DEN    $36,666           $0  $36,666
# 21957         Mac McCain  2021   CB  DEN    $36,666           $0  $36,666
# 21958    Joseph Charlton  2021    P  JAX    $36,666           $0  $36,666
# 21959       Danny Etling  2021   QB  JAX    $36,666           $0  $36,666
# 21960       Josh Hammond  2021   WR  JAX    $36,666           $0  $36,666
# 21961      Badara Traore  2021    T  JAX    $36,666           $0  $36,666
# 21962  Will Bradley-King  2021   DE  WAS    $36,666           $0  $36,666
# ...

# %%
# export to csv
financials_df_path = 'Resources/financials_r1.csv'
financials_df.to_csv(financials_df_path)
